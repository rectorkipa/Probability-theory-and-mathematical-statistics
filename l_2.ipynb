# %% [markdown]
# ## ДЗ по уроку № 2 (21.06.2022)
# ## Теория вероятности
# ### Дискретные случайные величины. Закон распределения вероятностей. Биномиальный закон распределения. Распределение Пуассона

# %% [markdown]
# **Пример 1**

# %% [markdown]
# Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.
# ________________________________________________
#
# Речь идет о биномиальном распределении, вероятность немалая - воспользуюсь формулой Бернули:

# %% [markdown]
# $$p(k=85) = C_n^kp^kq^{n-k} = C_100^85*0.8^85*0,2^15 = \frac{100!}{85!(100-85)!} \cdot 0.8^85 \cdot 0.2^15 = 100 * 99 * 98 * 97 * 96 * 95 * 94 * 93 * 92 * 91 * 90 * 89 * 88 * 87 * 86 * 85! / 85! * 15! * 0.8^85 * 0.2^15 = 331284225412682501619179520000 / 1307674368000 * 5,7896044618658097711785492504344e-9 * 0,000000000032768 = 0.0481$$

# %% [markdown]
# **Пример 2**

# %% [markdown]
# Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек. Какова вероятность, что ни одна из них не перегорит в первый день? Какова вероятность, что перегорят ровно две?
# ________________________________________________
#
# Здесь проводится большое количество испытаний n = 5000 и при этом вероятность  𝑝  перегорания  в отдельном испытании мала = 0.0004 - воспользуюсь формулой Пуассона (перегорит 0 или 2 лампочки):

# %% [markdown]
# $$P_m \approx \frac{\lambda^m}{m!}e^{-\lambda}$$

# %% [markdown]
# **где** $λ = np$ = 5000 * 0.0004 = 2.

# %% [markdown]
# $$P_0 \approx \frac{\lambda^m}{m!}e^{-\lambda}$$ = 2^0 / 0! * 2,7182818284590452353602874713527^-2 = 0.1353

# %% [markdown]
# $$P_2 \approx \frac{\lambda^m}{m!}e^{-\lambda}$$ = 2^2 / 2! * 2,7182818284590452353602874713527^-2 = 0.2707

# %% [markdown]
# **Пример 3**

# %% [markdown]
# Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?
# ________________________________________________
#
# Речь идет о биномиальном распределении, вероятность немалая (0.5) - воспользуюсь формулой Бернули (и онлайн-калькулятором):

# %% [markdown]
# $$p(k=70) = C_n^kp^kq^{n-k} = C_144^70p^3q^0 = \frac{144!}{70!(144-70)!} \cdot 0.5^70 \cdot 0.5^74 = 0.0628$$

# %% [markdown]
# **Пример 4**

# %% [markdown]
# В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча одновременно (можно решать и в иной постановке, т.е. что шары вытаскиваются не одновременно, важно лишь уточнить, что Вы имели в виду). Какова вероятность того, что все мячи белые? Какова вероятность того, что ровно два мяча белые? Какова вероятность того, что хотя бы один мяч белый?
# ________________________________________________
#
# Сначала найду общее число исходов - это число всех различных способов выбрать любые 2 мяча из общего числа 10 мячей в первом ящике (без учета порядка), то есть число сочетаний:

# %% [markdown]
# $$C_10^2 = \frac{10!}{2!(10-2)!}$$ =

# %% [markdown]
#  = 10 * 9 * 8! / 2! * 8! = 10 * 9 / 2 = 45

# %% [markdown]
# Теперь найду число всех способов выбрать 2 белых мяча из 7 возможных в первом ящике - это сочетания:

# %% [markdown]
# $$C_7^2 = \frac{7!}{2!(7-2)!}$$ =

# %% [markdown]
#  = 7 * 6 * 5! / 2! * 5! = 7 * 6 / 2 = 21

# %% [markdown]
# Применяя классическое определение вероятности, то есть поделив число благоприятствующих событию исходов на общее число исходов испытания (извлечения деталей), приду к искомой формуле (для первого ящика):

# %% [markdown]
# = 21 / 45 = 0.4667

# %% [markdown]
# А теперь найду общее число исходов для второго ящика - это число всех различных способов выбрать любые 2 мяча из общего числа 11 мячей во втором ящике (без учета порядка), то есть число сочетаний:

# %% [markdown]
# $$C_11^2 = \frac{11!}{2!(11-2)!}$$ =

# %% [markdown]
#  = 11 * 10 * 9! / 2! * 9! = 11 * 10 / 2 = 55

# %% [markdown]
# И теперь найду число всех способов выбрать 2 белых мяча из 9 возможных во втором ящике - это сочетания:

# %% [markdown]
# $$C_9^2 = \frac{9!}{2!(9-2)!}$$ =

# %% [markdown]
#  = 9 * 8 * 7! / 2! * 7! = 9 * 8 / 2 = 36

# %% [markdown]
# Применяя классическое определение вероятности, то есть поделив число благоприятствующих событию исходов на общее число исходов испытания (извлечения деталей), приду к искомой формуле (для второго ящика):

# %% [markdown]
# = 36 / 55 = 0.6545

# %% [markdown]
# Какова вероятность того, что все мячи белые?
#
# Перемножу полученные вероятности: 0.4667 * 0.6545 = 0,3055
# __________________________________________________________

# %% [markdown]
# Какова вероятность того, что ровно два мяча белые?
#
# Выстакиваются по два мяча одновременно - возможны следующие варианты:
# а) из первого ящика 2 белых, из второго 0;
# б) из первого ящика 1 белый, из второго 1 белый;
# в) из первого 0, из второго 2 белых.

# %% [markdown]
# а) 0.4667 + 0 = 0.4667

# %% [markdown]
# б) найду число всех способов выбрать 1 белый мяч из 7 возможных в первом ящике - это сочетания:

# %% [markdown]
# $$C_7^1 = \frac{7!}{1!(7-1)!}$$ =

# %% [markdown]
#  = 7 * 6! / 1! * 6! = 7 / 1 = 7

# %% [markdown]
# Применяя классическое определение вероятности, то есть поделив число благоприятствующих событию исходов на общее число исходов испытания (извлечения деталей), приду к искомой формуле (для первого ящика):

# %% [markdown]
# = 7 / 45 = 0.1555

# %% [markdown]
# Найду число всех способов выбрать 1 белый мяч из 9 возможных во втором ящике - это сочетания:

# %% [markdown]
# $$C_9^1 = \frac{9!}{1!(9-1)!}$$ =

# %% [markdown]
#  = 9 * 8! / 1! * 8! = 9 / 1 = 9

# %% [markdown]
# Применяя классическое определение вероятности, то есть поделив число благоприятствующих событию исходов на общее число исходов испытания (извлечения деталей), приду к искомой формуле (для второго ящика):

# %% [markdown]
# = 9 / 55 = 0.1636

# %% [markdown]
# 0.1555 + 0.1636 = 0,3191

# %% [markdown]
# в) 0 + 0.6545 = 0.6545
#
# Перемножу полученные вероятности: 0.4667 * 0,3191 * 0.6545 = 0,0974
# ______________________

# %% [markdown]
# Какова вероятность того, что хотя бы один мяч белый?
#
# Выстакиваются по два мяча одновременно - возможны следующие варианты:
# а) из первого ящика 1 белый, из второго 0;
# б) из первого 0, из второго 1 белый.

# %% [markdown]
# а) 0.1555 + 0 = 0.1555

# %% [markdown]
# б) 0 + 0.1636 = 0.1636
#
# Перемножу полученные вероятности: 0.1555 * 0.1636 = 0,0254
